# %%
import pandas as pd

# Load dataset
df = pd.read_csv(r"C:\Users\Yash\Downloads\archive (1)\AWCustomers.csv")

# %%
df.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...

# %%
df.drop(['Title','FirstName','MiddleName','LastName','Suffix','AddressLine2','AddressLine1','StateProvinceName'],axis=1)
# Out:
#        CustomerID            City CountryRegionName PostalCode  \
# 0           21173      Wollongong         Australia       2500
# 1           13249         Shawnee            Canada    V9B 2C3
# 2           29350     West Covina     United States      91791
# 3           13503       Liverpool    United Kingdom     L4 4HB
# 4           22803           Werne           Germany      59368
# ...           ...             ...               ...        ...
# 18356       25414        Coronado     United States      92118
# 18357       11459  Port Macquarie         Australia       2444
# 18358       12160       Beaverton     United States      97005
# 18359       14353       Vancouver            Canada    V7L 4J4
# 18360       16676       Grossmont     United States      91941
#
#                PhoneNumber   BirthDate        Education      Occupation  \
# 0      1 (11) 500 555-0115  1987-11-13        Bachelors        Clerical
# ...

# %%
 import pandas as pd

# %%
 print(pd.isna(df))
# Out:
#        CustomerID  Title  FirstName  MiddleName  LastName  Suffix  \
# 0           False   True      False       False     False    True
# 1           False   True      False        True     False    True
# 2           False   True      False        True     False    True
# 3           False   True      False        True     False    True
# 4           False   True      False       False     False    True
# ...           ...    ...        ...         ...       ...     ...
# 18356       False   True      False       False     False    True
# 18357       False   True      False        True     False    True
# 18358       False   True      False        True     False    True
# 18359       False   True      False       False     False    True
# 18360       False   True      False        True     False    True
#
#        AddressLine1  AddressLine2   City  StateProvinceName  ...  Education  \
# 0             False          True  False              False  ...      False
# ...

# %%
 df.fillna(method='pad')
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_18332\1822911545.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='pad')
#        CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0           21173   NaN      Chad          C      Yuan    NaN
# 1           13249   NaN      Ryan          C     Perry    NaN
# 2           29350   NaN     Julia          C  Thompson    NaN
# 3           13503   NaN  Theodore          C     Gomez    NaN
# 4           22803   NaN  Marshall          J      Shan    NaN
# ...           ...   ...       ...        ...       ...    ...
# 18356       25414   Ms.     Grace          C    Bailey    Jr.
# 18357       11459   Ms.     Tasha          C      Deng    Jr.
# 18358       12160   Ms.    Jaclyn          C     Zhang    Jr.
# 18359       14353   Ms.      Erin          I      Reed    Jr.
# ...

# %%
df.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['YearlyIncome']=scaler.fit_transform(df['YearlyIncome'].values.reshape(-1, 1)).flatten()

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['NumberCarsOwned']=scaler.fit_transform(df['NumberCarsOwned'].values.reshape(-1, 1)).flatten()

# %%
df.drop(['Title','FirstName','MiddleName','LastName','Suffix','AddressLine2','AddressLine1','StateProvinceName'],axis=1)
# Out:
#        CustomerID            City CountryRegionName PostalCode  \
# 0           21173      Wollongong         Australia       2500
# 1           13249         Shawnee            Canada    V9B 2C3
# 2           29350     West Covina     United States      91791
# 3           13503       Liverpool    United Kingdom     L4 4HB
# 4           22803           Werne           Germany      59368
# ...           ...             ...               ...        ...
# 18356       25414        Coronado     United States      92118
# 18357       11459  Port Macquarie         Australia       2444
# 18358       12160       Beaverton     United States      97005
# 18359       14353       Vancouver            Canada    V7L 4J4
# 18360       16676       Grossmont     United States      91941
#
#                PhoneNumber   BirthDate        Education      Occupation  \
# 0      1 (11) 500 555-0115  1987-11-13        Bachelors        Clerical
# ...

# %%
from sklearn.preprocessing import MaxAbsScaler
scaler =MaxAbsScaler()
df['TotalChildren']=scaler.fit_transform(df['TotalChildren'].values.reshape(-1, 1)).flatten()

# %%
print
# Out:
#        CustomerID            City CountryRegionName PostalCode  \
# 0           21173      Wollongong         Australia       2500
# 1           13249         Shawnee            Canada    V9B 2C3
# 2           29350     West Covina     United States      91791
# 3           13503       Liverpool    United Kingdom     L4 4HB
# 4           22803           Werne           Germany      59368
# ...           ...             ...               ...        ...
# 18356       25414        Coronado     United States      92118
# 18357       11459  Port Macquarie         Australia       2444
# 18358       12160       Beaverton     United States      97005
# 18359       14353       Vancouver            Canada    V7L 4J4
# 18360       16676       Grossmont     United States      91941
#
#                PhoneNumber   BirthDate        Education      Occupation  \
# 0      1 (11) 500 555-0115  1987-11-13        Bachelors        Clerical
# ...

# %%
import numpy as np

# %%
bins=np.linspace(min(df['YearlyIncome']),max(df['YearlyIncome']),4)
group_names=['min','mid','money']
df['YearlyIncome']=pd.cut(df['YearlyIncome'],bins,group_names,include_lowest=True)

# %%
df.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder = OneHotEncoder()
city_encoded = onehotencoder.fit_transform(df[['City']])

# %%
df.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...
