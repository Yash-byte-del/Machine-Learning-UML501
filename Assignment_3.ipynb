# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('AWCustomers.csv')
dataset.drop(['FirstName','LastName','Title',
              'City','Suffix','AddressLine2','Education'
              ,'BirthDate','MaritalStatus','PhoneNumber','NumberCarsOwned','NumberChildrenAtHome','LastUpdated'],axis=1,inplace=True)
dataset.fillna(0) 
dataset.dtypes
print(dataset.head())
# Out:
#    CustomerID MiddleName            AddressLine1    StateProvinceName  \
# 0       21173          C      7090 C. Mount Hood      New South Wales
# 1       13249        NaN     3651 Willow Lake Rd     British Columbia
# 2       29350        NaN  1774 Tice Valley Blvd.           California
# 3       13503        NaN         2103 Baldwin Dr              England
# 4       22803          J         Am Gallberg 234  Nordrhein-Westfalen
#
#   CountryRegionName PostalCode      Occupation Gender  HomeOwnerFlag  \
# 0         Australia       2500        Clerical      M              1
# 1            Canada    V9B 2C3        Clerical      M              1
# 2     United States      91791        Clerical      F              0
# 3    United Kingdom     L4 4HB  Skilled Manual      M              1
# 4           Germany      59368  Skilled Manual      M              1
#
#    TotalChildren  YearlyIncome
# 0              1         81916
# 1              2         81076
# 2              0         86387
# ...

# %%
dataset.fillna(method='pad')
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_24632\3167622817.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method='pad')
#        CustomerID MiddleName            AddressLine1    StateProvinceName  \
# 0           21173          C      7090 C. Mount Hood      New South Wales
# 1           13249          C     3651 Willow Lake Rd     British Columbia
# 2           29350          C  1774 Tice Valley Blvd.           California
# 3           13503          C         2103 Baldwin Dr              England
# 4           22803          J         Am Gallberg 234  Nordrhein-Westfalen
# ...           ...        ...                     ...                  ...
# 18356       25414          C      6627 Camelback Ct.           California
# 18357       11459          C         9627 Kendall Rd      New South Wales
# 18358       12160          C       4364 Viera Avenue               Oregon
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
dataset['YearlyIncome'] = scaler.fit_transform(dataset[['YearlyIncome']])
dataset
# Out:
#        CustomerID MiddleName            AddressLine1    StateProvinceName  \
# 0           21173          C      7090 C. Mount Hood      New South Wales
# 1           13249        NaN     3651 Willow Lake Rd     British Columbia
# 2           29350        NaN  1774 Tice Valley Blvd.           California
# 3           13503        NaN         2103 Baldwin Dr              England
# 4           22803          J         Am Gallberg 234  Nordrhein-Westfalen
# ...           ...        ...                     ...                  ...
# 18356       25414          C      6627 Camelback Ct.           California
# 18357       11459        NaN         9627 Kendall Rd      New South Wales
# 18358       12160        NaN       4364 Viera Avenue               Oregon
# 18359       14353          I  3866 Mt. Everest Court     British Columbia
# 18360       16676        NaN     7870 Orangewood Dr.           California
#
#       CountryRegionName PostalCode      Occupation Gender  HomeOwnerFlag  \
# ...
